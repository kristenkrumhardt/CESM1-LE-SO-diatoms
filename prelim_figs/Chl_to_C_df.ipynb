# %%
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
import os
from glob import glob
from collections import OrderedDict
import xarray as xr
import numpy as np

import esmlab
import matplotlib.pyplot as plt
import cartopy
import cartopy.crs as ccrs
from scipy import stats
import pop_tools 

from statistics import mean
from matplotlib import style
from scipy import stats
import pandas as pd

style.use('default')
import matplotlib.path as mpath

from IPython.display import Image

# %% [markdown]
# coldwater species = above 40° latitude

# %%
df = pd.read_csv('Chl_C_ratios_v2.csv')

# %%
df
# Out:
#    PFT_group                                       study  \
# 0       diat                           Lomas et al. 2019
# 1       diat                           Lomas et al. 2019
# 2       diat                           Lomas et al. 2019
# 3       diat                           Lomas et al. 2019
# 4       diat                           Lomas et al. 2019
# 5       diat                           Lomas et al. 2019
# 6       diat                           Lomas et al. 2019
# 7       diat                           Lomas et al. 2019
# 8       diat                           Lomas et al. 2019
# 9       diat               Geider et al. 1997,Yoder 1979
# 10        sp             Geider et al. 1997,Langdon 1987
# 11      diat             Geider et al. 1997,Landgon 1987
# 12        sp      Geider et al. 1997,Kana & Gilbert 1987
# 13        sp             Geider et al. 1997,Nielsen 1996
# 14        sp             Geider et al. 1997,Nielsen 1992
# 15        sp    Geider et al. 1997,Falkowski et al. 1985
# 16      diat    Geider et al. 1997,Falkowski et al. 1985
# 17        sp  Geider et al. 1997,Muggali & Harrison 1997
# 18        sp                          Verity et al. 1991
# 19      diat                        Sakshaug et al. 1991
# 20      diat                        Sakshaug et al. 1991
# 21      diat                                 Verity 1982
# 22      diat                       MacIntyre et al. 2002
# 23        sp                                Nielsen 1997
# 24        sp                        Garcia & Prudie 1992
# 25        sp                          Arrigo et al. 2010
# 26        sp                          Arrigo et al. 2010
# 27      diat                          Arrigo et al. 2010
# 28      diat                                Hedseth 1989
# 29      diat                                Hedseth 1989
# 30      diat                                Hedseth 1989
# 31      diat                          Lacour et al. 2016
# 32      diat                          Lacour et al. 2016
#
#                           species  \
# 0         Attheya septentrionalis
# 1              Skeletonema dohrni
# 2              Porosira glacialis
# 3            Melosira nummuloides
# 4                Odontella aurita
# 5        Thalassiosira antarctica
# 6   Thalassiosira nordenskioeldii
# 7        Thalassiosira aestivalis
# 8           Thalassiosira gravida
# 9            Skeletonema costatum
# 10           Olisthodiscus luteus
# 11           Skeletonema costatum
# 12            Synecchococcus spp.
# 13        Gymnodinium galatheanum
# 14            Gyrodinium aureolum
# 15            Prorocentrum micans
# 16      Thalassiosira weissflogii
# 17              Emiliania huxleyi
# 18          Phaeocystis pouchetti
# 19  Thalassiosira nordenskioeldii
# 20        Chaetoceros furcellatus
# 21       Leptocylindricus danicus
# 22      Thalassiosira tricornutum
# 23              Emiliania huxleyi
# 24        Gyrodinium cf. aureolum
# 25    Phaeocystis antarctica 1871
# 26    Phaeocystis antarctica 1374
# 27       Fragilariopsis cylindrus
# 28        Chaetoceros furcellatus
# 29       Thalassiosira antarctica
# 30        Nitzschia delicatissima
# 31         Chaetoceros néogracile
# 32          Thalassiosira gravida
#
#                                  isolate_location  gChl/gC  \
# 0    Baffin Bay (77.8N, 76.4W), N. Atlantic Ocean   0.1300
# 1            Kasitsna Bay (59.5N, 151.4W), Alaska   0.0400
# 2   Narragansett Bay (41.6N, 71.4W), Rhode Island   0.0610
# 3      Harwich Harbor (41.7N, 70W), Massachusetts   0.0400
# 4      Webb Cove 44.2N, 69.5W), Stonington, Maine   0.0530
# 5              Oslo Fjord (59.5N, −10.6W), Norway   0.0550
# 6                  Tromsø (69.7N, −18.7W), Norway   0.0730
# 7             North Atlantic Ocean (42.7N, 69.6W)   0.0430
# 8                  Tromsø (59.5N, −10.6W), Norway   0.0610
# 9   Narragansett Bay (41.6N, 71.4W), Rhode Island   0.0470
# 10  Narragansett Bay (41.6N, 71.4W), Rhode Island   0.0330
# 11  Narragansett Bay (41.6N, 71.4W), Rhode Island   0.0440
# 12                            33 44.9’N 67 29.8’W   0.0210
# 13                              Olsofjord, Norway   0.0150
# 14                              Olsofjord, Norway   0.0470
# 15                    unknown; Long Island Sounds   0.0070
# 16                              Long Island Sound   0.0550
# 17             Subarctic North Pacific, Station P   0.0170
# 18                                 Tromso, Norway   0.0150
# 19                                    Barents Sea   0.0620
# 20                                    Barents Sea   0.0360
# 21  Narragansett Bay (41.6N, 71.4W), Rhode Island   0.0360
# 22       worldwide distribution; Scottish isolate   0.0620
# 23                 Plymouth Marine Laboratory, UK   0.0280
# 24                                English Channel   0.0240
# 25                                 Southern Ocean   0.0240
# 26                                 Southern Ocean   0.0150
# 27                                 Southern Ocean   0.0400
# 28                                          polar   0.0360
# 29                                          polar   0.0380
# 30                                          polar   0.0385
# 31                                          polar   0.0380
# 32                                          polar   0.0420
#
#                                                notes
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
# 10                      found in Lacour et al., 2016
# 11                                               NaN
# 12        isolate location found in Chadd et al 1996
# 13                                               NaN
# 14                                               NaN
# 15                                               NaN
# 16                                               NaN
# 17                                               NaN
# 18  largest value reported among solitary & colonies
# 19                           low light adapted, 12 h
# 20                           low light adapted, 12 h
# 21                       found in Lacour et al. 2016
# 22                       found in Lacour et al. 2016
# 23                       found in Lacour et al. 2016
# 24                                    dinoflagellate
# 25                                               NaN
# 26                                               NaN
# 27                                               NaN
# 28                                    Arctic species
# 29                                    Arctic species
# 30                                    Arctic species
# 31                                               NaN
# 32       found in Lacour et al. 2016; arctic species

# %% [markdown]
# ### CESM diat gChl/gC:
# #### diat: 0.046
# #### sp: 0.028

# %%
selection_diat = df[(df['PFT_group'] =='diat')]
selection_diat['gChl/gC'].mean()
# Out:
# 0.05138636363636366

# %%
selection_sp = df[(df['PFT_group'] =='sp')]
selection_sp['gChl/gC'].mean()
# Out:
# 0.022363636363636363

# %% [markdown]
# ### make a bar plot

# %%
species_diat = np.asarray(selection_diat.species)
species_sp = np.asarray(selection_sp.species)
#species_diat

# %%
ratio_diat = np.asarray(selection_diat['gChl/gC'])
ratio_sp = np.asarray(selection_sp['gChl/gC'])
#ratio_diat

# %%
fig = plt.figure(figsize=(8,4))
ax = fig.add_subplot(1,2,1)
ax.set_ylim(0,0.14)
ax.set_title('a) Diatoms', x=0.15)
ax.bar(species_diat,ratio_diat, color='red')
ax.set_ylabel('max gChl/gC')
ax.tick_params(axis='x', labelrotation = 90)
plt.axhline(y=selection_diat['gChl/gC'].mean(), color='lightcoral', linestyle='--',label='mean observations')
plt.axhline(y=0.046, color='black', linestyle='--', label='CESM')
ax.legend()

ax = fig.add_subplot(1,2,2)
ax.set_ylim(0,0.14)
ax.set_title('b) Small phytoplankton',x=0.3)
ax.bar(species_sp,ratio_sp, color='blue')
ax.tick_params(axis='x', labelrotation = 90)
ax.set_ylabel('max gChl/gC')
plt.axhline(y=selection_sp['gChl/gC'].mean(), color='lightskyblue', linestyle='--',label='mean observations')
plt.axhline(y=0.028, color='black', linestyle='--', label='CESM')
ax.yaxis.set_label_position("right")
ax.legend()
ax.yaxis.tick_right();

fig.subplots_adjust(wspace=0.05)

fig.savefig('/glade/work/kristenk/figs/max_theta-sp-diat.png', bbox_inches='tight', dpi=300, format='png');

# %%
selection_diat
# Out:
#    PFT_group                                     study  \
# 0       diat                         Lomas et al. 2019
# 1       diat                         Lomas et al. 2019
# 2       diat                         Lomas et al. 2019
# 3       diat                         Lomas et al. 2019
# 4       diat                         Lomas et al. 2019
# 5       diat                         Lomas et al. 2019
# 6       diat                         Lomas et al. 2019
# 7       diat                         Lomas et al. 2019
# 8       diat                         Lomas et al. 2019
# 9       diat             Geider et al. 1997,Yoder 1979
# 11      diat           Geider et al. 1997,Landgon 1987
# 16      diat  Geider et al. 1997,Falkowski et al. 1985
# 19      diat                      Sakshaug et al. 1991
# 20      diat                      Sakshaug et al. 1991
# 21      diat                               Verity 1982
# 22      diat                     MacIntyre et al. 2002
# 27      diat                        Arrigo et al. 2010
# 28      diat                              Hedseth 1989
# 29      diat                              Hedseth 1989
# 30      diat                              Hedseth 1989
# 31      diat                        Lacour et al. 2016
# 32      diat                        Lacour et al. 2016
#
#                           species  \
# 0         Attheya septentrionalis
# 1              Skeletonema dohrni
# 2              Porosira glacialis
# 3            Melosira nummuloides
# 4                Odontella aurita
# 5        Thalassiosira antarctica
# 6   Thalassiosira nordenskioeldii
# 7        Thalassiosira aestivalis
# 8           Thalassiosira gravida
# 9            Skeletonema costatum
# 11           Skeletonema costatum
# 16      Thalassiosira weissflogii
# 19  Thalassiosira nordenskioeldii
# 20        Chaetoceros furcellatus
# 21       Leptocylindricus danicus
# 22      Thalassiosira tricornutum
# 27       Fragilariopsis cylindrus
# 28        Chaetoceros furcellatus
# 29       Thalassiosira antarctica
# 30        Nitzschia delicatissima
# 31         Chaetoceros néogracile
# 32          Thalassiosira gravida
#
#                                  isolate_location  gChl/gC  \
# 0    Baffin Bay (77.8N, 76.4W), N. Atlantic Ocean   0.1300
# 1            Kasitsna Bay (59.5N, 151.4W), Alaska   0.0400
# 2   Narragansett Bay (41.6N, 71.4W), Rhode Island   0.0610
# 3      Harwich Harbor (41.7N, 70W), Massachusetts   0.0400
# 4      Webb Cove 44.2N, 69.5W), Stonington, Maine   0.0530
# 5              Oslo Fjord (59.5N, −10.6W), Norway   0.0550
# 6                  Tromsø (69.7N, −18.7W), Norway   0.0730
# 7             North Atlantic Ocean (42.7N, 69.6W)   0.0430
# 8                  Tromsø (59.5N, −10.6W), Norway   0.0610
# 9   Narragansett Bay (41.6N, 71.4W), Rhode Island   0.0470
# 11  Narragansett Bay (41.6N, 71.4W), Rhode Island   0.0440
# 16                              Long Island Sound   0.0550
# 19                                    Barents Sea   0.0620
# 20                                    Barents Sea   0.0360
# 21  Narragansett Bay (41.6N, 71.4W), Rhode Island   0.0360
# 22       worldwide distribution; Scottish isolate   0.0620
# 27                                 Southern Ocean   0.0400
# 28                                          polar   0.0360
# 29                                          polar   0.0380
# 30                                          polar   0.0385
# 31                                          polar   0.0380
# 32                                          polar   0.0420
#
#                                           notes
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# 5                                           NaN
# 6                                           NaN
# 7                                           NaN
# 8                                           NaN
# 9                                           NaN
# 11                                          NaN
# 16                                          NaN
# 19                      low light adapted, 12 h
# 20                      low light adapted, 12 h
# 21                  found in Lacour et al. 2016
# 22                  found in Lacour et al. 2016
# 27                                          NaN
# 28                               Arctic species
# 29                               Arctic species
# 30                               Arctic species
# 31                                          NaN
# 32  found in Lacour et al. 2016; arctic species

# %%
selection_sp
# Out:
#    PFT_group                                       study  \
# 10        sp             Geider et al. 1997,Langdon 1987
# 12        sp      Geider et al. 1997,Kana & Gilbert 1987
# 13        sp             Geider et al. 1997,Nielsen 1996
# 14        sp             Geider et al. 1997,Nielsen 1992
# 15        sp    Geider et al. 1997,Falkowski et al. 1985
# 17        sp  Geider et al. 1997,Muggali & Harrison 1997
# 18        sp                          Verity et al. 1991
# 23        sp                                Nielsen 1997
# 24        sp                        Garcia & Prudie 1992
# 25        sp                          Arrigo et al. 2010
# 26        sp                          Arrigo et al. 2010
#
#                         species  \
# 10         Olisthodiscus luteus
# 12          Synecchococcus spp.
# 13      Gymnodinium galatheanum
# 14          Gyrodinium aureolum
# 15          Prorocentrum micans
# 17            Emiliania huxleyi
# 18        Phaeocystis pouchetti
# 23            Emiliania huxleyi
# 24      Gyrodinium cf. aureolum
# 25  Phaeocystis antarctica 1871
# 26  Phaeocystis antarctica 1374
#
#                                  isolate_location  gChl/gC  \
# 10  Narragansett Bay (41.6N, 71.4W), Rhode Island    0.033
# 12                            33 44.9’N 67 29.8’W    0.021
# 13                              Olsofjord, Norway    0.015
# 14                              Olsofjord, Norway    0.047
# 15                    unknown; Long Island Sounds    0.007
# 17             Subarctic North Pacific, Station P    0.017
# 18                                 Tromso, Norway    0.015
# 23                 Plymouth Marine Laboratory, UK    0.028
# 24                                English Channel    0.024
# 25                                 Southern Ocean    0.024
# 26                                 Southern Ocean    0.015
#
#                                                notes
# 10                      found in Lacour et al., 2016
# 12        isolate location found in Chadd et al 1996
# 13                                               NaN
# 14                                               NaN
# 15                                               NaN
# 17                                               NaN
# 18  largest value reported among solitary & colonies
# 23                       found in Lacour et al. 2016
# 24                                    dinoflagellate
# 25                                               NaN
# 26                                               NaN

# %%
species_diat
# Out:
# array(['Attheya septentrionalis', 'Skeletonema dohrni',
#        'Porosira glacialis', 'Melosira nummuloides', 'Odontella aurita',
#        'Thalassiosira antarctica', 'Thalassiosira nordenskioeldii',
#        'Thalassiosira aestivalis', 'Thalassiosira gravida',
#        'Skeletonema costatum', 'Skeletonema costatum',
#        'Thalassiosira weissflogii', 'Thalassiosira nordenskioeldii',
#        'Chaetoceros furcellatus', 'Leptocylindricus danicus',
#        'Thalassiosira tricornutum', 'Fragilariopsis cylindrus',
#        'Chaetoceros furcellatus', 'Thalassiosira antarctica',
#        'Nitzschia delicatissima', 'Chaetoceros néogracile',
#        'Thalassiosira gravida'], dtype=object)

# %%
species_diat2 = ['Attheya septentrionalis$^1$', 'Skeletonema dohrni$^1$',
       'Porosira glacialis$^1$', 'Melosira nummuloides$^1$', 'Odontella aurita$^1$',
       'Thalassiosira antarctica$^1$', 'Thalassiosira nordenskioeldii$^1$',
       'Thalassiosira aestivalis$^1$', 'Thalassiosira gravida$^1$',
       'Skeletonema costatum$^2$', 'Skeletonema costatum$^3$',
       'Thalassiosira weissflogii$^4$', 'Thalassiosira nordenskioeldii$^5$',
       'Chaetoceros furcellatus$^5$', 
       'Leptocylindricus danicus$^6$', 'Thalassiosira tricornutum$^7$',
       'Fragilariopsis cylindrus$^8$', 'Chaetoceros furcellatus$^{9}$',
       'Thalassiosira antarctica$^{9}$', 'Nitzschia delicatissima$^{9}$',
       'Chaetoceros néogracile$^{10}$', 'Thalassiosira gravida$^{10}$']

# %%
species_sp2 =['Olisthodiscus luteus$^3$', 'Synecchococcus spp.$^{11}$',
       'Gymnodinium galatheanum$^{12}$', 'Gyrodinium aureolum$^{13}$',
       'Prorocentrum micans$^{4}$', 'Emiliania huxleyi$^{14}$',
       'Phaeocystis pouchetti$^{15}$', 'Emiliania huxleyi$^{16}$',
       'Gyrodinium cf. aureolum$^{17}$', 'Phaeocystis antarctica 1871$^{8}$',
       'Phaeocystis antarctica 1374$^{8}$']

# %%
fig = plt.figure(constrained_layout=True,figsize=(8,4))
ax = fig.add_gridspec(1, 3)

ax1 = fig.add_subplot(ax[0:2])
ax1.set_ylim(0,0.14)
ax1.set_title('A) Diatoms', x=0.15,fontweight='bold')
ax1.bar(species_diat2,ratio_diat, color='red')
ax1.set_ylabel('max gChl/gC')
ax1.tick_params(axis='x', labelrotation = 90)
plt.axhline(y=selection_diat['gChl/gC'].mean(), color='lightcoral', linestyle='--',label='mean observations')
plt.axhline(y=0.046, color='black', linestyle='--', label='CESM')
ax1.legend()
plt.xticks(fontsize=10)

ax2 = fig.add_subplot(ax[2:3])
ax2.set_ylim(0,0.14)
ax2.set_title('B) Other phytoplankton',x=0.45,fontweight='bold')
ax2.bar(species_sp2,ratio_sp, color='blue')
ax2.tick_params(axis='x', labelrotation = 90)
ax2.set_ylabel('max gChl/gC')
plt.axhline(y=selection_sp['gChl/gC'].mean(), color='lightskyblue', linestyle='--',label='mean observations')
plt.axhline(y=0.028, color='black', linestyle='--', label='CESM')
ax2.yaxis.set_label_position("right")
ax2.legend()
ax2.yaxis.tick_right();
plt.xticks(fontsize=10)

# plt.rcParams.update(fontparams)

fig.subplots_adjust(wspace=0.05)
fig.savefig('/glade/work/kristenk/figs/Chl_to_C_ratio_SIfig.png', bbox_inches='tight', dpi=300, format='png');
