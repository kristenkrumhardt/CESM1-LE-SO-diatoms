# %% [markdown]
# # Calculate HTL productivity using the Stock et al (2017, PNAS) empiracal formula, applied to CESM in Moore et al. (2018)

# %%
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
import os
from glob import glob
#from collections import OrderedDict
import xarray as xr
import numpy as np
#import dask
#from ncar_jobqueue import NCARCluster
import esmlab
import matplotlib.pyplot as plt
import cartopy
import cartopy.crs as ccrs
from scipy import stats
import pop_tools 

from statistics import mean
from matplotlib import style
from scipy import stats
import matplotlib.path as mpath
#style.use('ggplot')

# %% [markdown]
# ### Get the CESM-LE variables (annual means calculated in cesm-le-annual-means-v2.ipynb)

# %%
# %%time
path = '/glade/scratch/kristenk/CESM-LE-output/CESM-LE-'
variables = ['zoo_prod_zint','diatC_zint','spC_zint','zooC_zint']

ds_list = []
ds = xr.Dataset()

for v in variables:  
    print(v)
    files = sorted(glob(f'{path}{v}.nc'))  
    dsv=xr.open_mfdataset(files, data_vars="minimal", coords='minimal', compat="override", parallel=True, concat_dim="time",
                       drop_variables=["transport_components", "transport_regions"], decode_times=True)
    
    ds = xr.merge((ds, dsv))
    ds_list.append(ds)
# Out:
# zoo_prod_zint
# diatC_zint
# spC_zint
# zooC_zint
# CPU times: user 216 ms, sys: 15.9 ms, total: 232 ms
# Wall time: 626 ms

# %%
ds['mesozooC'] = ds.zooC_zint * (ds.diatC_zint/(ds.diatC_zint + ds.spC_zint))
ds['diat_frac'] = ds.diatC_zint/(ds.diatC_zint + ds.spC_zint)

variables = variables + ['mesozooC','diat_frac']

# %% [markdown]
# ### Necessary plotting function

# %%
def adjust_pop_grid(tlon,tlat,field):
    nj = tlon.shape[0]
    ni = tlon.shape[1]
    xL = int(ni/2 - 1)
    xR = int(xL + ni)

    tlon = np.where(np.greater_equal(tlon,min(tlon[:,0])),tlon-360.,tlon)
    lon  = np.concatenate((tlon,tlon+360.),1)
    lon = lon[:,xL:xR]

    if ni == 320:
        lon[367:-3,0] = lon[367:-3,0]+360.
    lon = lon - 360.
    lon = np.hstack((lon,lon[:,0:1]+360.))
    if ni == 320:
        lon[367:,-1] = lon[367:,-1] - 360.

    #-- trick cartopy into doing the right thing:
    #   it gets confused when the cyclic coords are identical
    lon[:,0] = lon[:,0]-1e-8
    
    #-- periodicity
    lat  = np.concatenate((tlat,tlat),1)
    lat = lat[:,xL:xR]
    lat = np.hstack((lat,lat[:,0:1]))

    field = np.ma.concatenate((field,field),1)
    field = field[:,xL:xR]
    field = np.ma.hstack((field,field[:,0:1]))
    return lon,lat,field

# %% [markdown]
# ### get pop grid

# %%
grid = pop_tools.get_grid('POP_gx1v6')

# %%
grid.REGION_MASK.plot()

# %%
lons = grid.TLONG
lats = grid.TLAT
years = ds.time.values
years
# Out:
# array([1920, 1921, 1922, 1923, 1924, 1925, 1926, 1927, 1928, 1929, 1930,
#        1931, 1932, 1933, 1934, 1935, 1936, 1937, 1938, 1939, 1940, 1941,
#        1942, 1943, 1944, 1945, 1946, 1947, 1948, 1949, 1950, 1951, 1952,
#        1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963,
#        1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974,
#        1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985,
#        1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996,
#        1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007,
#        2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018,
#        2019, 2020, 2021, 2022, 2023, 2024, 2025, 2026, 2027, 2028, 2029,
#        2030, 2031, 2032, 2033, 2034, 2035, 2036, 2037, 2038, 2039, 2040,
#        2041, 2042, 2043, 2044, 2045, 2046, 2047, 2048, 2049, 2050, 2051,
#        2052, 2053, 2054, 2055, 2056, 2057, 2058, 2059, 2060, 2061, 2062,
#        2063, 2064, 2065, 2066, 2067, 2068, 2069, 2070, 2071, 2072, 2073,
#        2074, 2075, 2076, 2077, 2078, 2079, 2080, 2081, 2082, 2083, 2084,
#        2085, 2086, 2087, 2088, 2089, 2090, 2091, 2092, 2093, 2094, 2095,
#        2096, 2097, 2098, 2099, 2100])

# %% [markdown]
# ### mask out nans in ds

# %%
ds = ds.where(grid.REGION_MASK>0)

# %%
ds.zoo_prod_zint.isel(time=60,member_id=22).plot()

# %% [markdown]
# ### Extract 1920s

# %%
ds.time.isel(time=slice(0,10)).values
# Out:
# array([1920, 1921, 1922, 1923, 1924, 1925, 1926, 1927, 1928, 1929])

# %%
ds_1920s = ds.isel(time=slice(0,10)).mean(dim='time')

# %% [markdown]
# ### Extract 1990s

# %%
ds.time.isel(time=slice(70,80)).values
# Out:
# array([1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999])

# %%
ds_1990s = ds.isel(time=slice(70,80)).mean(dim='time')

# %% [markdown]
# ### Extract 2090s

# %%
ds.time.isel(time=slice(-11,-1)).values
# Out:
# array([2090, 2091, 2092, 2093, 2094, 2095, 2096, 2097, 2098, 2099])

# %%
ds_2090s = ds.isel(time=slice(-11,-1)).mean(dim='time')

# %%
mask3d = pop_tools.region_mask_3d('POP_gx1v6', mask_name='lat-range-basin')
mask3d.isel(region=1).plot()

# %%
# %%time

ts_SO = xr.Dataset({v: ds[v] for v in ['time','member_id']})

for v in variables:
    
    masked = ds[v].where(mask3d.isel(region=1)==1)
    ts_SO[v] = esmlab.weighted_mean(masked, weights=grid.TAREA, dim=['nlat', 'nlon']).compute()
# Out:
# CPU times: user 48.4 s, sys: 1min 11s, total: 1min 59s
# Wall time: 3min 13s

# %%
ts_SO_ens_mean = ts_SO.mean(dim='member_id')

# %%
ens_mean_1920s = ds_1920s.mean(dim='member_id')

# %%
ens_mean_1990s = ds_1990s.mean(dim='member_id')

# %%
ens_mean_2090s = ds_2090s.mean(dim='member_id')

# %%
convert = 0.01 * 86400. * 365. * 0.001 # to convert from mmol/m3 cm/s to mol/m2/y

# %% [markdown]
# ### zoo production

# %%
style.use('default')
fig, ax = plt.subplots(nrows=1,ncols=3,figsize=(14,5))
ax[0].set_title('a) Zooplankton production')
ax[0].set_ylabel('zoo production (mol C m$^{-2}$ y$^{-1}$)')
ax[0].set_ylim(1.4,2.05)
for mem in np.arange(0,34,1):

    ax[0].plot(years, 
         ts_SO['zoo_prod_zint'].isel(member_id=mem) * convert, 
         color='pink')

ax[0].plot(years, ts_SO_ens_mean['zoo_prod_zint'] * convert, 
         color='red')

############

ax[1].set_title('b) Zooplankton biomass')
ax[1].set_ylabel('zooplankton C (mmol m$^{-2}$)')
ax[1].set_ylim(75,85)
for mem in np.arange(0,34,1):

    ax[1].plot(years, 
         ts_SO['zooC_zint'].isel(member_id=mem), 
         color='lightblue')

ax[1].plot(years, ts_SO_ens_mean['zooC_zint'], 
         color='blue');

############

ax[2].set_title('c) Large zooplankton biomass')
ax[2].set_ylabel('meso/macrozooplankton (mmol m$^{-2}$)')
ax[2].set_ylim(31,43)
for mem in np.arange(0,34,1):

    ax[2].plot(years, 
         ts_SO['mesozooC'].isel(member_id=mem), 
         color='lightgreen')

ax[2].plot(years, ts_SO_ens_mean['mesozooC'], 
         color='green')

#fig.savefig('/glade/work/kristenk/figs/zoo_ts_CESM-le.png', bbox_inches='tight', dpi=300, format='png');
fig.savefig('/glade/work/kristenk/figs/zoo_ts_CESM-le.png', bbox_inches='tight', dpi=300, format='png');

# %%
fig = plt.figure(figsize=(10,9))

ax = fig.add_subplot(3,1,1, projection=ccrs.Robinson(central_longitude=305.0))
lon, lat, field = adjust_pop_grid(lons, lats, ens_mean_1990s['zoo_prod_zint'] * convert)

ax.set_title('total zooplankton production, ensemble mean over the 1990s', fontsize=12)
ax.coastlines('10m',linewidth=0.5)
pc=ax.pcolormesh(lon, lat, field, cmap='jet',transform=ccrs.PlateCarree())

cbar1 = fig.colorbar(pc, ax=ax,extend='max',label='mmol C m$^{-2}$ y${-1}$')

ax = fig.add_subplot(3,1,2, projection=ccrs.Robinson(central_longitude=305.0))
lon, lat, field = adjust_pop_grid(lons, lats, ens_mean_2090s['zoo_prod_zint'] * convert)

ax.set_title('total zooplankton production, ensemble mean over the 2090s', fontsize=12)
ax.coastlines('10m',linewidth=0.5)
pc=ax.pcolormesh(lon, lat, field, cmap='jet',transform=ccrs.PlateCarree())

cbar1 = fig.colorbar(pc, ax=ax,extend='max',label='mmol C m$^{-2}$ y${-1}$')

ax = fig.add_subplot(3,1,3, projection=ccrs.Robinson(central_longitude=305.0))
lon, lat, field = adjust_pop_grid(lons, lats, (ens_mean_2090s['zoo_prod_zint']- ens_mean_1990s['zoo_prod_zint']) * convert)

ax.set_title('total zooplankton production, 2090s - 1990s', fontsize=12)
ax.coastlines('10m',linewidth=0.5)
pc=ax.pcolormesh(lon, lat, field, cmap='bwr',transform=ccrs.PlateCarree())

cbar1 = fig.colorbar(pc, ax=ax,extend='both',label='mmol C m$^{-2}$ y${-1}$')

# %%
fig = plt.figure(figsize=(5,4))


#----------PLOT MEAN STATE---------------------------------------------------
lon, lat, field = adjust_pop_grid(lons, lats,  ens_mean_2090s['zoo_prod_zint'] * convert- ens_mean_1990s['zoo_prod_zint'] * convert)
sh = lat[:, 0] < 0
lon = lon[sh, :]
lat = lat[sh, :]
field = field[sh, :]

ax = fig.add_subplot(1,1,1, projection=ccrs.SouthPolarStereo())
ax.set_title('${\Delta}$ Zooplankton production')
ax.set_extent([-180, 180, -90, -30], ccrs.PlateCarree())

#################### make it a circle
theta = np.linspace(0, 2*np.pi, 100)
center, radius = [0.5, 0.5], 0.5
verts = np.vstack([np.sin(theta), np.cos(theta)]).T
circle = mpath.Path(verts * radius + center)

ax.set_boundary(circle, transform=ax.transAxes)
#################### end circle

cf = ax.pcolormesh(lon,lat,field, vmin=-1,vmax=1,
                     transform=ccrs.PlateCarree(),cmap='bwr')

ax.coastlines('110m',linewidth=1)
cbar1 = fig.colorbar(cf, ax=ax,extend='both',label='mmol C m$^{-2}$ y$^{-1}$')
cbar1.set_label(label='mmol C m$^{-2}$ y$^{-1}$', fontsize='12')
cbar1.ax.tick_params(labelsize=12)

# %%
fig = plt.figure(figsize=(5,4))


#----------PLOT MEAN STATE---------------------------------------------------
lon, lat, field = adjust_pop_grid(lons, lats,  (ens_mean_2090s['zooC_zint']- ens_mean_1920s['zooC_zint']))
sh = lat[:, 0] < 0
lon = lon[sh, :]
lat = lat[sh, :]
field = field[sh, :]

ax = fig.add_subplot(1,1,1, projection=ccrs.SouthPolarStereo())
ax.set_title('${\Delta}$ Zooplankton biomass')
ax.set_extent([-180, 180, -90, -30], ccrs.PlateCarree())

#################### make it a circle
theta = np.linspace(0, 2*np.pi, 100)
center, radius = [0.5, 0.5], 0.5
verts = np.vstack([np.sin(theta), np.cos(theta)]).T
circle = mpath.Path(verts * radius + center)

ax.set_boundary(circle, transform=ax.transAxes)
#################### end circle

cf = ax.pcolormesh(lon,lat,field,
                     transform=ccrs.PlateCarree(),cmap='bwr', vmin=-10, vmax=10)

ax.coastlines('110m',linewidth=0.5)

cbar1 = fig.colorbar(cf, ax=ax,extend='both')
cbar1.set_label(label='mmol m$^{-2}$', fontsize='12')
cbar1.ax.tick_params(labelsize=12)

# %%
fig = plt.figure(figsize=(5,4))


#----------PLOT MEAN STATE---------------------------------------------------
lon, lat, field = adjust_pop_grid(lons, lats,  (ens_mean_2090s['mesozooC']- ens_mean_1990s['mesozooC']))
sh = lat[:, 0] < 0
lon = lon[sh, :]
lat = lat[sh, :]
field = field[sh, :]

ax = fig.add_subplot(1,1,1, projection=ccrs.SouthPolarStereo())
ax.set_title('${\Delta}$ meso/macrozooplankton biomass')
ax.set_extent([-180, 180, -90, -30], ccrs.PlateCarree())

#################### make it a circle
theta = np.linspace(0, 2*np.pi, 100)
center, radius = [0.5, 0.5], 0.5
verts = np.vstack([np.sin(theta), np.cos(theta)]).T
circle = mpath.Path(verts * radius + center)

ax.set_boundary(circle, transform=ax.transAxes)
#################### end circle

cf = ax.pcolormesh(lon,lat,field,
                     transform=ccrs.PlateCarree(),cmap='bwr', vmin=-10, vmax=10)

ax.coastlines('110m',linewidth=0.5)

cbar1 = fig.colorbar(cf, ax=ax,extend='both',label='mmol C m$^{-2}$')
cbar1.set_label(label='mmol C m$^{-2}$', fontsize='12')
cbar1.ax.tick_params(labelsize=12)
